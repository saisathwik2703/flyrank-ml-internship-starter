# %% [markdown]
# <a href="https://colab.research.google.com/github/saisathwik2703/flyrank-ml-internship-starter/blob/main/notebooks/02_your_first_readable_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2 — The model is just a rule you can read
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/saisathwik2703/flyrank-ml-internship-starter/blob/main/notebooks/02_your_first_readable_model.ipynb?flush_cache=true)
#
# You'll:
# 1. Write a **1-line hand rule** and rank pages with it.
# 2. Fit a **depth-2 decision tree** and `print` it — the model "learned" a readable if/else. Then compare — where does it beat your rule, and where doesn’t it?
# 3. See **why you never feed the outcome back in** — that's leakage.
#
# The payoff isn't a high score. It's: *my intuition was rough, the model found the real signal, and I can read exactly what it found.*

# %% [markdown]
# ## 0. Setup (Colab or local)

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

import pandas as pd, numpy as np
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# The label: a page is 'declining' when its recent trend is down. Simple, honest starter label.
df["is_declining_label"] = df["trend_direction"].str.lower().eq("down").astype(int)
print(df.shape[0], "pages |  declining rate:", round(df["is_declining_label"].mean(), 3))
# Out:
# 30000 pages |  declining rate: 0.542

# %% [markdown]
# ## 1. A rule you write by hand: `stale x visible`
# Intuition: a page worth reviewing is one that is **stale** (not updated in a while) **and** still **visible** (getting impressions). Rank those by how much exposure they have.

# %%
stale   = (df["days_since_last_update"] >= 180).astype(int)
visible = (df["impressions_90d"] >= 500).astype(int)
df["hand_rule_score"] = stale * visible * df["impressions_90d"]

top10 = df.sort_values("hand_rule_score", ascending=False).head(10)
top10[["impressions_90d", "days_since_last_update", "avg_position", "ctr", "trend_direction"]]
# Out:
#        impressions_90d  days_since_last_update  avg_position   ctr  \
# 16751            61678                     194          19.7  0.15
# 16514            59472                     194          24.8  0.13
# 7021             25715                     194          22.2  0.23
# 21268            13299                     193          10.5  0.49
# 11489             7812                     194          39.0  0.01
# 12045             7558                     193          17.9  0.20
# 698               4590                     194          31.0  0.00
# 5327              4556                     194          16.4  0.33
# 26810             4429                     194          25.3  0.38
# 20837             1697                     193          15.8  0.12
#
#       trend_direction
# 16751            down
# 16514            down
# 7021             down
# 21268            down
# 11489            down
# 12045            down
# 698              down
# 5327             down
# 26810            down
# 20837            down

# %% [markdown]
# We need a way to score any ranking. **Precision@K** = of the top K pages a ranking flags, what fraction are actually declining.

# %%
def precision_at_k(scores, labels, k):
    order = np.argsort(-np.asarray(scores))
    topk = np.asarray(labels)[order[:k]]
    return topk.mean()

y = df["is_declining_label"].values
for k in (20, 50):
    print(f"Hand rule  Precision@{k}: {precision_at_k(df['hand_rule_score'], y, k):.3f}")
# Out:
# Hand rule  Precision@20: 0.900
# Hand rule  Precision@50: 0.680

# %% [markdown]
# ## 2. Let a model learn the rule — then read it
# A **depth-2 decision tree** can only ask 3 yes/no questions. That constraint is the point: whatever it learns, you can read.
#
# We give it a few **pre-decision** signals — never product flags.

# %%
from sklearn.tree import DecisionTreeClassifier, export_text

features = ["content_age_days", "days_since_last_update", "impressions_90d",
            "avg_position", "ctr", "word_count"]
X = df[features].replace([np.inf, -np.inf], np.nan).fillna(0)

tree = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42)
tree.fit(X, y)

print(export_text(tree, feature_names=features))
# Out:
# |--- impressions_90d <= 5.50
# |   |--- avg_position <= 0.75
# |   |   |--- class: 0
# |   |--- avg_position >  0.75
# |   |   |--- class: 0
# |--- impressions_90d >  5.50
# |   |--- content_age_days <= 312.50
# |   |   |--- class: 1
# |   |--- content_age_days >  312.50
# |   |   |--- class: 0

# %% [markdown]
# That printout **is** the model — a human-readable if/else. Now rank pages by the tree's probability and score it the same way.

# %%
tree_score = tree.predict_proba(X)[:, 1]
for k in (20, 50):
    hr = precision_at_k(df["hand_rule_score"], y, k)
    tr = precision_at_k(tree_score, y, k)
    print(f"Precision@{k}:  hand rule {hr:.3f}   vs   tree {tr:.3f}")
# Out:
# Precision@20:  hand rule 0.900   vs   tree 0.550
# Precision@50:  hand rule 0.680   vs   tree 0.600

# %% [markdown]
# Now read your own printout carefully — **the winner here depends on your run.** A depth-2 tree can only give four different scores (one per leaf), so the "top 50" is mostly one big block of tied pages, and different library versions break those ties differently. On some stacks the tree wins at Precision@50; on others the hand rule holds both. **Both results are real.** The stable lesson: a sharp human rule can be excellent at the very top of the list; a model's advantage — when it shows up — appears deeper, where simple rules run out of signal; and any comparison built on heavily tied scores is fragile. Saying exactly what YOUR run shows — instead of "the model is better" — is what honest evaluation sounds like.

# %% [markdown]
# ## 3. Why you can't feed the outcome back in
# Your label is `trend_direction == "down"`, and `trend_pct` is the exact percentage change that bucket is computed from — so it **is** the answer in disguise. Watch what happens if you feed it in as a feature:

# %%
X_leaky = df[features + ["trend_pct"]].replace([np.inf, -np.inf], np.nan).fillna(0)
leaky = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42).fit(X_leaky, y)
print(f"'Leaky' tree Precision@50: {precision_at_k(leaky.predict_proba(X_leaky)[:,1], y, 50):.3f}  <- looks amazing")
print(export_text(leaky, feature_names=features + ["trend_pct"]))
# Out:
# 'Leaky' tree Precision@50: 1.000  <- looks amazing
# |--- trend_pct <= -20.05
# |   |--- word_count <= 212.00
# |   |   |--- class: 1
# |   |--- word_count >  212.00
# |   |   |--- class: 1
# |--- trend_pct >  -20.05
# |   |--- trend_pct <= -19.95
# |   |   |--- class: 0
# |   |--- trend_pct >  -19.95
# |   |   |--- class: 0

# %% [markdown]
# The tree just split on `trend_pct` and nailed the label — because the label is **derived from** `trend_pct`. That's **leakage**: the feature is the answer in disguise, and it teaches you nothing.
#
# That's also why the starter data ships **only observable signals** — the product's own decision flags (health scores, "needs CTR fix", and so on) aren't included, so you can't accidentally train on them. You build from what was knowable *before* the outcome.
#
# > Rule of thumb: if a feature would only be known *because someone already made the decision you're predicting*, it leaks. Leave it out.

# %% [markdown]
# ## 4. 🔧 Your turn
# - Change `max_depth` to 3 or 4 — does Precision@50 improve? Can you still read the tree?
# - Swap in different features (drop `impressions_90d`, add `engagement_rate`). What does the tree choose to split on first?
# - **Important caveat:** we scored *in-sample* here for teaching. The real pipeline uses **client-holdout** validation (`scripts/03_train_model.py`) so a client's pages never appear in both train and test. Re-run your comparison with a train/test split and see if the gap holds.
#
# Write your experiment below.

# %%
# Your experiment here
# ============================================================
# 4. YOUR EXPERIMENT
# ============================================================

from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.model_selection import GroupShuffleSplit

# ------------------------------------------------------------
# 1. Find the client column for client-holdout validation
# ------------------------------------------------------------

possible_client_cols = [
    "client_id",
    "client",
    "clientid",
    "site_id",
    "customer_id"
]

client_col = next(
    (col for col in possible_client_cols if col in df.columns),
    None
)

if client_col is None:
    raise ValueError(
        "Client column not found. Run: print(df.columns.tolist()) "
        "and check the correct client column name."
    )

print("Client column used:", client_col)


# ------------------------------------------------------------
# 2. Create a client-holdout train/test split
# ------------------------------------------------------------

splitter = GroupShuffleSplit(
    n_splits=1,
    test_size=0.20,
    random_state=42
)

train_idx, test_idx = next(
    splitter.split(df, y, groups=df[client_col])
)

print("Training rows:", len(train_idx))
print("Testing rows :", len(test_idx))


# ------------------------------------------------------------
# 3. Function to clean features
# ------------------------------------------------------------

def make_X(feature_list):
    return (
        df[feature_list]
        .replace([np.inf, -np.inf], np.nan)
        .fillna(0)
    )


# ------------------------------------------------------------
# 4. Experiment 1 — depth 2, 3 and 4
# ------------------------------------------------------------

base_features = [
    "content_age_days",
    "days_since_last_update",
    "impressions_90d",
    "avg_position",
    "ctr",
    "word_count"
]

print("\n===== DEPTH EXPERIMENT =====")

for depth in [2, 3, 4]:

    X = make_X(base_features)

    tree = DecisionTreeClassifier(
        max_depth=depth,
        class_weight="balanced",
        random_state=42
    )

    tree.fit(
        X.iloc[train_idx],
        y[train_idx]
    )

    test_score = tree.predict_proba(
        X.iloc[test_idx]
    )[:, 1]

    p20 = precision_at_k(
        test_score,
        y[test_idx],
        20
    )

    p50 = precision_at_k(
        test_score,
        y[test_idx],
        50
    )

    print(
        f"Depth {depth}: "
        f"Precision@20 = {p20:.3f}, "
        f"Precision@50 = {p50:.3f}"
    )

    print("\nReadable tree:")
    print(
        export_text(
            tree,
            feature_names=base_features
        )
    )


# ------------------------------------------------------------
# 5. Experiment 2 — drop impressions_90d
#    and add engagement_rate
# ------------------------------------------------------------

print("\n===== FEATURE EXPERIMENT =====")

alternative_features = [
    "content_age_days",
    "days_since_last_update",
    "avg_position",
    "ctr",
    "word_count",
    "engagement_rate"
]

missing_features = [
    col for col in alternative_features
    if col not in df.columns
]

if missing_features:
    print(
        "These features are not available:",
        missing_features
    )
else:

    X_alt = make_X(alternative_features)

    tree_alt = DecisionTreeClassifier(
        max_depth=3,
        class_weight="balanced",
        random_state=42
    )

    tree_alt.fit(
        X_alt.iloc[train_idx],
        y[train_idx]
    )

    alt_score = tree_alt.predict_proba(
        X_alt.iloc[test_idx]
    )[:, 1]

    alt_p20 = precision_at_k(
        alt_score,
        y[test_idx],
        20
    )

    alt_p50 = precision_at_k(
        alt_score,
        y[test_idx],
        50
    )

    print(
        f"Alternative features: "
        f"Precision@20 = {alt_p20:.3f}, "
        f"Precision@50 = {alt_p50:.3f}"
    )

    print("\nReadable alternative tree:")
    print(
        export_text(
            tree_alt,
            feature_names=alternative_features
        )
    )


# ------------------------------------------------------------
# 6. Show which feature the tree uses first
# ------------------------------------------------------------

print("\n===== FEATURE IMPORTANCE =====")

importance = pd.Series(
    tree_alt.feature_importances_,
    index=alternative_features
).sort_values(ascending=False)

print(importance)


# ------------------------------------------------------------
# 7. Final interpretation
# ------------------------------------------------------------

print("\n===== EXPERIMENT SUMMARY =====")

print(
    "The experiment compares decision-tree depths 2, 3 and 4 "
    "using client-holdout validation."
)

print(
    "The alternative experiment removes impressions_90d and "
    "adds engagement_rate."
)

print(
    "trend_pct is intentionally excluded because it is derived "
    "from the outcome and would cause target leakage."
)
# Out:
# Client column used: client_id
# Training rows: 23837
# Testing rows : 6163
#
# ===== DEPTH EXPERIMENT =====
# Depth 2: Precision@20 = 0.600, Precision@50 = 0.560
#
# Readable tree:
# |--- impressions_90d <= 5.50
# |   |--- avg_position <= 0.75
# |   |   |--- class: 0
# |   |--- avg_position >  0.75
# |   |   |--- class: 0
# |--- impressions_90d >  5.50
# |   |--- content_age_days <= 312.50
# |   |   |--- class: 1
# |   |--- content_age_days >  312.50
# |   |   |--- class: 0
#
# Depth 3: Precision@20 = 0.550, Precision@50 = 0.580
#
# Readable tree:
# |--- impressions_90d <= 5.50
# |   |--- avg_position <= 0.75
# |   |   |--- impressions_90d <= 3.50
# |   |   |   |--- class: 0
# |   |   |--- impressions_90d >  3.50
# |   |   |   |--- class: 0
# |   |--- avg_position >  0.75
# |   |   |--- content_age_days <= 108.50
# |   |   |   |--- class: 0
# |   |   |--- content_age_days >  108.50
# |   |   |   |--- class: 0
# |--- impressions_90d >  5.50
# |   |--- content_age_days <= 312.50
# |   |   |--- ctr <= 0.30
# |   |   |   |--- class: 1
# |   |   |--- ctr >  0.30
# |   |   |   |--- class: 1
# |   |--- content_age_days >  312.50
# |   |   |--- avg_position <= 24.45
# |   |   |   |--- class: 0
# |   |   |--- avg_position >  24.45
# |   |   |   |--- class: 0
#
# Depth 4: Precision@20 = 0.550, Precision@50 = 0.600
#
# Readable tree:
# |--- impressions_90d <= 5.50
# |   |--- avg_position <= 0.75
# |   |   |--- impressions_90d <= 3.50
# |   |   |   |--- word_count <= 687.00
# |   |   |   |   |--- class: 0
# |   |   |   |--- word_count >  687.00
# |   |   |   |   |--- class: 0
# |   |   |--- impressions_90d >  3.50
# |   |   |   |--- content_age_days <= 309.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- content_age_days >  309.50
# |   |   |   |   |--- class: 1
# |   |--- avg_position >  0.75
# |   |   |--- content_age_days <= 108.50
# |   |   |   |--- content_age_days <= 93.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- content_age_days >  93.50
# |   |   |   |   |--- class: 0
# |   |   |--- content_age_days >  108.50
# |   |   |   |--- word_count <= 705.00
# |   |   |   |   |--- class: 0
# |   |   |   |--- word_count >  705.00
# |   |   |   |   |--- class: 0
# |--- impressions_90d >  5.50
# |   |--- content_age_days <= 312.50
# |   |   |--- ctr <= 0.30
# |   |   |   |--- impressions_90d <= 46.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- impressions_90d >  46.50
# |   |   |   |   |--- class: 1
# |   |   |--- ctr >  0.30
# |   |   |   |--- ctr <= 0.88
# |   |   |   |   |--- class: 1
# |   |   |   |--- ctr >  0.88
# |   |   |   |   |--- class: 0
# |   |--- content_age_days >  312.50
# |   |   |--- avg_position <= 24.45
# |   |   |   |--- days_since_last_update <= 12.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- days_since_last_update >  12.50
# |   |   |   |   |--- class: 0
# |   |   |--- avg_position >  24.45
# |   |   |   |--- word_count <= 894.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- word_count >  894.50
# |   |   |   |   |--- class: 0
#
#
# ===== FEATURE EXPERIMENT =====
# Alternative features: Precision@20 = 0.700, Precision@50 = 0.580
#
# Readable alternative tree:
# |--- avg_position <= 1.05
# |   |--- avg_position <= 0.55
# |   |   |--- word_count <= 4.00
# |   |   |   |--- class: 0
# |   |   |--- word_count >  4.00
# |   |   |   |--- class: 0
# |   |--- avg_position >  0.55
# |   |   |--- content_age_days <= 167.00
# |   |   |   |--- class: 1
# |   |   |--- content_age_days >  167.00
# |   |   |   |--- class: 0
# |--- avg_position >  1.05
# |   |--- content_age_days <= 287.50
# |   |   |--- ctr <= 0.30
# |   |   |   |--- class: 1
# |   |   |--- ctr >  0.30
# |   |   |   |--- class: 1
# |   |--- content_age_days >  287.50
# |   |   |--- days_since_last_update <= 23.50
# |   |   |   |--- class: 0
# |   |   |--- days_since_last_update >  23.50
# |   |   |   |--- class: 1
#
#
# ===== FEATURE IMPORTANCE =====
# avg_position              0.501526
# content_age_days          0.338211
# days_since_last_update    0.090906
# ctr                       0.067615
# word_count                0.001741
# engagement_rate           0.000000
# dtype: float64
#
# ===== EXPERIMENT SUMMARY =====
# The experiment compares decision-tree depths 2, 3 and 4 using client-holdout validation.
# The alternative experiment removes impressions_90d and adds engagement_rate.
# trend_pct is intentionally excluded because it is derived from the outcome and would cause target leakage.

# %% [markdown]
# ### Save your work
# **Colab:** *File → Save a copy in GitHub* (your submission) and *File → Save a copy in Drive*.
#
# You now have the two core reflexes of applied ML: **discover before you model**, and **prefer a model you can read and can't fool**. That's the whole foundation the capstone builds on.
